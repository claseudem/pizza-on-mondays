# %%
import yfinance as yf

# %%
stock = yf.Ticker("UEC")

# %%
stock
# Out:
# yfinance.Ticker object <UEC>

# %%
stock.info
# Out:
# {'address1': '500 North Shoreline',
#  'address2': 'Suite 800N',
#  'city': 'Corpus Christi',
#  'state': 'TX',
#  'zip': '78401',
#  'country': 'United States',
#  'phone': '361 888 8235',
#  'fax': '361 888 5041',
#  'website': 'https://www.uraniumenergy.com',
#  'industry': 'Uranium',
#  'industryKey': 'uranium',
#  'industryDisp': 'Uranium',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Uranium Energy Corp., together with its subsidiaries, engages in exploration, pre-extraction, extraction, and processing of uranium and titanium concentrates properties in the United States, Canada, and the Republic of Paraguay. The company was formerly known as Carlin Gold Inc. and changed its name to Uranium Energy Corp. in January 2005. The company was incorporated in 2003 and is headquartered in Corpus Christi, Texas.',
#  'fullTimeEmployees': 171,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Amir  Adnani',
#    'age': 47,
# ...

# %%
stock.calendar
# Out:
# {'Earnings Date': [datetime.date(2026, 9, 24)],
#  'Earnings High': -0.01,
#  'Earnings Low': -0.01,
#  'Earnings Average': -0.01,
#  'Revenue High': 9000000,
#  'Revenue Low': 9000000,
#  'Revenue Average': 9000000}

# %%
stock.analyst_price_targets
# Out:
# {'current': 11.36,
#  'high': 26.75,
#  'low': 12.0,
#  'mean': 18.02778,
#  'median': 17.0}

# %%
stock.option_chain(stock.options[0]).calls
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   UEC260814C00001000 2026-08-12 15:50:00+00:00     1.0      10.47  9.85
# 1   UEC260814C00002000 2026-08-12 15:50:16+00:00     2.0       9.47  8.70
# 2   UEC260814C00004000 2026-08-12 15:28:19+00:00     4.0       7.60  6.60
# 3   UEC260814C00005000 2026-08-12 16:31:52+00:00     5.0       6.50  5.40
# 4   UEC260814C00005500 2026-08-12 14:13:01+00:00     5.5       6.25  5.35
# 5   UEC260814C00006000 2026-08-12 14:15:26+00:00     6.0       5.54  4.75
# 6   UEC260814C00006500 2026-08-12 14:15:26+00:00     6.5       5.11  3.85
# 7   UEC260814C00007000 2026-08-12 16:58:47+00:00     7.0       4.43  3.85
# 8   UEC260814C00007500 2026-08-12 15:56:02+00:00     7.5       3.91  2.99
# 9   UEC260814C00008500 2026-08-12 18:11:31+00:00     8.5       2.95  2.65
# 10  UEC260814C00009000 2026-08-11 19:37:37+00:00     9.0       2.43  2.10
# 11  UEC260814C00009500 2026-08-10 13:30:01+00:00     9.5       1.85  1.75
# ...

# %%
tickers = yf.Tickers('MSFT AAPL GOOG')

# %%
datos = yf.download(['UEC'], period='1mo')["Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
datos
# Out:
# Ticker        UEC
# Date
# 2026-07-13  10.07
# 2026-07-14  10.39
# 2026-07-15  10.11
# 2026-07-16   9.33
# 2026-07-17   9.28
# 2026-07-20   9.40
# 2026-07-21   9.55
# 2026-07-22   9.73
# 2026-07-23   9.83
# 2026-07-24   9.51
# 2026-07-27   9.91
# 2026-07-28   9.44
# 2026-07-29   9.04
# 2026-07-30   9.74
# 2026-07-31   9.60
# 2026-08-03   9.97
# 2026-08-04  10.50
# 2026-08-05  10.72
# 2026-08-06  10.76
# 2026-08-07  11.26
# 2026-08-10  11.38
# 2026-08-11  11.46
# 2026-08-12  11.36

# %%
datos.to_excel("/workspaces/pizza-on-mondays/src/data/datos.xlsx")
